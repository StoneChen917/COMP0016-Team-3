# %%
# !pip install transformers
from transformers import BertForQuestionAnswering
model = BertForQuestionAnswering.from_pretrained('deepset/bert-base-cased-squad2')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 42.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.4/182.4 KB 24.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 53.1 MB/s eta 0:00:00
# ...
# Downloading:   0%|          | 0.00/508 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/433M [00:00<?, ?B/s]

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained('deepset/bert-base-cased-squad2')
# Out:
# Downloading:   0%|          | 0.00/152 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
questions = ["What was done to promote water, sanitation and hygiene?", "What are the names of all other partner organizations actively involved in the operation?", "What does the UN want to stabilize?"]

questions
# Out:
# ['What was done to promote water, sanitation and hygiene?',
#  'What are the names of all other partner organizations actively involved in the operation?',
#  'What does the UN want to stabilize?']

# %%
tokenizer.encode(questions[0], truncation = True, padding = True)
# Out:
# [101,
#  1327,
#  1108,
#  1694,
#  1106,
#  4609,
#  1447,
#  117,
#  23353,
#  1105,
#  177,
#  21431,
#  136,
#  102]

# %%
tokenizer.encode('[CLS]')
# Out:
# [101, 101, 102]

# %%
from transformers import pipeline
nlp = pipeline('question-answering', model = model, tokenizer = tokenizer)

# %%
# importing required modules
# !pip install PyPDF2
from PyPDF2 import PdfReader

# creating a pdf file object
pdfFileObj = open('/content/MDRRW014dfr.pdf', 'rb')

# creating a pdf reader object
pdfReader = PdfReader(pdfFileObj)

# printing number of pages in pdf file
print(len(pdfReader.pages))

# creating a page object
pageObj = pdfReader.pages[6]

# extracting text from page
context = pageObj.extract_text()


# closing the pdf file object
pdfFileObj.close()

print(context)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 KB 8.9 MB/s eta 0:00:00
# ...
# 14
# Page  | 7
#
# DREF Operation plan–  “insert operation name” - Update No.  was identified there was less need for mosquito nets, and therefore this was red uced from 540 to 270 nets.
# Procurement of First -aid kits was also increased from 2 to 4 kits.
#
# Challenges
# No challenges were encountered
#
# Lessons learned
# • There was timely distribution of NFI’s, mosquito nets and kitenge
# • The volunteers and community found health and hygiene sensitization using mobile cinema very interesting and useful.
#
#
#
# Water, Sanitation and Hygiene Promotion
#
# Needs analysis: Following the storm and heavy wind, sanitation infrastructures were destroyed; while the storm and
# heavy wind- affected population were  displaced and were living with families in nearby communities, which became
# ...

# %% [markdown]
# # New Section

# %%
nlp({'question': questions[0], 'context': context})
# Out:
# {'score': 0.018090005964040756,
#  'start': 944,
#  'end': 991,
#  'answer': 'distribution of hygiene related non- food items'}
