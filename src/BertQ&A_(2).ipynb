# %% [markdown]
# <a href="https://colab.research.google.com/github/StoneChen917/COMP0016-Team-3/blob/main/BertQ%26A_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! python -m pip install 'traitlets==4.3.3' --force-reinstall
# Out:
# Failed to start the Kernel.
#
# Kernel Python 3.10.2 is not usable. Check the Jupyter output tab for more information.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
! pip install ipykernel --upgrade
# Out:
# Failed to start the Kernel.
#
# Kernel Python 3.10.2 is not usable. Check the Jupyter output tab for more information.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from transformers import BertForQuestionAnswering
model = BertForQuestionAnswering.from_pretrained('bert-base-uncased')
# Out:
# Failed to start the Kernel.
#
# Kernel Python 3.10.2 is not usable. Check the Jupyter output tab for more information.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
# Out:
# Failed to start the Kernel.
#
# Kernel Python 3.10.2 is not usable. Check the Jupyter output tab for more information.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#questions1 = "start date?"
#questions2 = "end date?"
#questions3 = "Glide Number?"
#questions4 = "operation number?"
#questions5 = "budget?"
#questions6 = "country of disaster?"
#questions7 = "host national society?"

# %%
tokenizer.encode("operation number", truncation = True, padding = True)
#tokenizer.encode('[CLS]')
from transformers import pipeline
nlp = pipeline('question-answering', model = model, tokenizer = tokenizer)
# importing required modules
# !pip install PyPDF2
from PyPDF2 import PdfReader

# creating a pdf file object
pdfFileObj = open('MDRRW014dfr (1).pdf', 'rb')

# creating a pdf reader object
pdfReader = PdfReader(pdfFileObj)

# printing number of pages in pdf file
print(len(pdfReader.pages))

# creating a page object
pageObj = pdfReader.pages[6]

# extracting text from page
context = pageObj.extract_text()


# closing the pdf file object
pdfFileObj.close()

#print(context)

nlp({'question': "operation number", 'context': context})
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# 14
# {'score': 4.640374027076177e-05,
#  'start': 3102,
#  'end': 3148,
#  'answer': 'In total 7  mobile cinema on hygiene promotion'}

# %%
tokenizer.encode("Glide Number", truncation = True, padding = True)
#tokenizer.encode('[CLS]')
from transformers import pipeline
nlp = pipeline('question-answering', model = model, tokenizer = tokenizer)
# importing required modules
# !pip install PyPDF2
from PyPDF2 import PdfReader

# creating a pdf file object
pdfFileObj = open('MDRRW014dfr (1).pdf', 'rb')

# creating a pdf reader object
pdfReader = PdfReader(pdfFileObj)

# printing number of pages in pdf file
print(len(pdfReader.pages))

# creating a page object
pageObj = pdfReader.pages[6]

# extracting text from page
context = pageObj.extract_text()


# closing the pdf file object
pdfFileObj.close()

#print(context)

nlp({'question': "Glide Number", 'context': context})
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# 14
# {'score': 4.7180044930428267e-05,
#  'start': 3131,
#  'end': 3148,
#  'answer': 'hygiene promotion'}

# %%
tokenizer.encode("start date", truncation = True, padding = True)
#tokenizer.encode('[CLS]')
from transformers import pipeline
nlp = pipeline('question-answering', model = model, tokenizer = tokenizer)
# importing required modules
# !pip install PyPDF2
from PyPDF2 import PdfReader

# creating a pdf file object
pdfFileObj = open('MDRRW014dfr (1).pdf', 'rb')

# creating a pdf reader object
pdfReader = PdfReader(pdfFileObj)

# printing number of pages in pdf file
print(len(pdfReader.pages))

# creating a page object
pageObj = pdfReader.pages[6]

# extracting text from page
context = pageObj.extract_text()


# closing the pdf file object
pdfFileObj.close()

#print(context)

nlp({'question': "start date", 'context': context})
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# 14
# {'score': 4.581116445478983e-05,
#  'start': 3102,
#  'end': 3148,
#  'answer': 'In total 7  mobile cinema on hygiene promotion'}

# %%
tokenizer.encode("end date", truncation = True, padding = True)
#tokenizer.encode('[CLS]')
from transformers import pipeline
nlp = pipeline('question-answering', model = model, tokenizer = tokenizer)
# importing required modules
# !pip install PyPDF2
from PyPDF2 import PdfReader

# creating a pdf file object
pdfFileObj = open('MDRRW014dfr (1).pdf', 'rb')

# creating a pdf reader object
pdfReader = PdfReader(pdfFileObj)

# printing number of pages in pdf file
print(len(pdfReader.pages))

# creating a page object
pageObj = pdfReader.pages[6]

# extracting text from page
context = pageObj.extract_text()


# closing the pdf file object
pdfFileObj.close()

#print(context)

nlp({'question': "end date", 'context': context})
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# 14
# {'score': 4.555958730634302e-05,
#  'start': 3102,
#  'end': 3148,
#  'answer': 'In total 7  mobile cinema on hygiene promotion'}

# %%
tokenizer.encode("budget", truncation = True, padding = True)
#tokenizer.encode('[CLS]')
from transformers import pipeline
nlp = pipeline('question-answering', model = model, tokenizer = tokenizer)
# importing required modules
# !pip install PyPDF2
from PyPDF2 import PdfReader

# creating a pdf file object
pdfFileObj = open('MDRRW014dfr (1).pdf', 'rb')

# creating a pdf reader object
pdfReader = PdfReader(pdfFileObj)

# printing number of pages in pdf file
print(len(pdfReader.pages))

# creating a page object
pageObj = pdfReader.pages[6]

# extracting text from page
context = pageObj.extract_text()


# closing the pdf file object
pdfFileObj.close()

#print(context)

nlp({'question': "budget", 'context': context})
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# 14
# {'score': 4.17224619013723e-05,
#  'start': 3102,
#  'end': 3148,
#  'answer': 'In total 7  mobile cinema on hygiene promotion'}

# %%
tokenizer.encode("country of disaster", truncation = True, padding = True)
#tokenizer.encode('[CLS]')
from transformers import pipeline
nlp = pipeline('question-answering', model = model, tokenizer = tokenizer)
# importing required modules
# !pip install PyPDF2
from PyPDF2 import PdfReader

# creating a pdf file object
pdfFileObj = open('MDRRW014dfr (1).pdf', 'rb')

# creating a pdf reader object
pdfReader = PdfReader(pdfFileObj)

# printing number of pages in pdf file
print(len(pdfReader.pages))

# creating a page object
pageObj = pdfReader.pages[6]

# extracting text from page
context = pageObj.extract_text()


# closing the pdf file object
pdfFileObj.close()

#print(context)

nlp({'question': "country of disaster", 'context': context})

# %%
tokenizer.encode("host national society", truncation = True, padding = True)
#tokenizer.encode('[CLS]')
from transformers import pipeline
nlp = pipeline('question-answering', model = model, tokenizer = tokenizer)
# importing required modules
# !pip install PyPDF2
from PyPDF2 import PdfReader

# creating a pdf file object
pdfFileObj = open('MDRRW014dfr (1).pdf', 'rb')

# creating a pdf reader object
pdfReader = PdfReader(pdfFileObj)

# printing number of pages in pdf file
print(len(pdfReader.pages))

# creating a page object
pageObj = pdfReader.pages[6]

# extracting text from page
context = pageObj.extract_text()


# closing the pdf file object
pdfFileObj.close()

#print(context)

nlp({'question': "host national society", 'context': context})
